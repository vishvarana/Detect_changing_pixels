# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage import transform
import cv2
images = [cv2.imread(image,0) for image in glob.glob("C:/Users/Yuvraj/Desktop/Vishva/Frames/*.jpg")]

# %%
i = 10
for frame in [i,i+1]:
    plt.imshow(cv2.cvtColor(images[frame],cv2.COLOR_BGR2RGB))
    plt.title("frame :"+str(frame))
    plt.show()

# %%
plt.imshow(cv2.absdiff(images[10],images[11]))
plt.show()

# %%
diff = cv2.absdiff(images[10],images[11])

ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)

plt.imshow(thresh,cmap='gray')
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
dilated = cv2.dilate(thresh, kernel, iterations=1)
plt.imshow(dilated,cmap='gray')
plt.show()

# %%
for i in range(0,49):
    if i==0:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[0])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(1) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(49,99):
    if i==49:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[49])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(50) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(99,149):
    if i==99:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[99])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(100) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(149,199):
    if i==149:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[149])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(150) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(199,249):
    if i==199:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[199])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(200) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(249,299):
    if i==249:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[249])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(250) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(299,349):
    if i==299:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[299])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(300) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(349,399):
    if i==349:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[349])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(350) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
for i in range(399,410):
    if i==399:
        name = 'C:/Users/Yuvraj/Desktop/Vishva/Diff' + '/' +'key_f' + str(i+1) + '.jpg'
        cv2.imwrite(name, images[i])
        print('Creating ' + name)
    else :
        diff = cv2.absdiff(images[i],images[399])
        ret,thresh = cv2.threshold(diff,30,255,cv2.THRESH_BINARY)
        dilated = cv2.dilate(thresh, kernel, iterations=1)
        name = "C:/Users/Yuvraj/Desktop/Vishva/Diff" + "/" + "diff" + str(i+1) + "-" + str(400) + ".jpg"
        cv2.imwrite(name,dilated)
        print('Creating ' + name)
# Out:
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/key_f1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff2-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff3-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff4-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff5-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff6-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff7-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff8-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff9-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff10-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff11-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff12-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff13-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff14-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff15-1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/Diff/diff16-1.jpg
# ...
